# %%
#Exercise 2: Handwritten Digit Recognition


from sklearn.datasets import load_digits

digits = load_digits()
X, y = digits.data, digits.target  # 1797 digits, 64 pixels, 10 classes (0-9)

# Your Task:
# 1. Prepare Data
# 2. Build a model for 10 classes (digits 0-9)
# 3. Define Loss and Optimizer
# 4. Use 64 input features (8x8 pixel images)
# 5. Train and see if you can get >90% accuracy
# Out:
# array([0, 1, 2, ..., 8, 9, 8])
